# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter

# %%
img_in = 'cs3-10-quiz.jpg'
img = Image.open(img_in)

# %%
plt.imshow(img)
plt.show()

# %%
print(img.format, img.size,
      img.width, img.height, img.mode)
# Out:
# JPEG (1920, 2560) 1920 2560 RGB

# %%
data = np.array(img) 
print(data.shape)
# Out:
# (2560, 1920, 3)

# %%
img_rot = img.rotate(-30)

# %%
plt.imshow(img_rot)
plt.show()

# %%
img_rot.save('cs3-10-quiz-rot.jpg', quality=95)
