# %% [markdown]
# ### Training of CNN

# %% [markdown]
# #### Import libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from tensorflow.keras.layers import Dropout,Flatten,Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.utils import to_categorical

import  os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # for mac OS

# %% [markdown]
# #### Uncomment these lines to fix random sequences

# %%
#import random
#import tensorflow as tf
#seedval = 13
#tf.random.set_seed(seedval)
#np.random.seed(seedval)
#random.seed(seedval)
#os.environ["PYTHONHASHSEED"] = str(seedval)

# %% [markdown]
# #### Parameters

# %%
w=56
work_dir='data/dogs_cats'
npy_data_base='dogs_cats-data'
npy_labels_base='dogs_cats-labels'
classes=['cats', 'dogs']
num_classes=len(classes)

model_file="dogs_cats-model-w{}.h5".format(w)
history_file="dogs_cats-history-w{}.csv".format(w)

# %% [markdown]
# #### Read files and convert data format

# %%
mode="train"
npy_data_file='{}-{}-w{}.npy'.format(npy_data_base, mode, w)
data_file_path=os.path.join(work_dir, npy_data_file)
npy_labels_file='{}-{}-w{}.npy'.format(npy_labels_base, mode, w)
labels_file_path=os.path.join(work_dir, npy_labels_file)
X_train=np.load(data_file_path).astype('float16')
X_train/=255
print(X_train.shape)
y_train=np.load(labels_file_path)
y_train=to_categorical(y_train, num_classes)

mode="test"
npy_data_file='{}-{}-w{}.npy'.format(npy_data_base, mode, w)
data_file_path=os.path.join(work_dir, npy_data_file)
npy_labels_file='{}-{}-w{}.npy'.format(npy_labels_base, mode, w)
labels_file_path=os.path.join(work_dir, npy_labels_file)
X_test=np.load(data_file_path).astype("float16")
X_test/=255
y_test=np.load(labels_file_path)
y_test=to_categorical(y_test, num_classes)

print( X_train.shape )
print( y_train.shape )
print( X_test.shape )
print( y_test.shape )
img_rows=X_train.shape[1]
img_cols=X_train.shape[2]
img_channels=X_train.shape[3]
print("image_size:", img_rows, img_cols)
print("image_channels:", img_channels)
# Out:
# (2000, 56, 56, 3)
# (2000, 56, 56, 3)
# (2000, 2)
# (400, 56, 56, 3)
# (400, 2)
# image_size: 56 56
# image_channels: 3

# %% [markdown]
# #### Structure of CNN

# %%
input_shape=(img_rows,img_cols,img_channels)
model=Sequential()
model.add(Conv2D(32, (3,3), activation='relu', padding='same',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 56, 56, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 32)       0
#  )
#
#  dropout (Dropout)           (None, 28, 28, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 64)                100416
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 119,938
# Trainable params: 119,938
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Training of CNN

# %%
# %%time
n_epochs=100
val_split=0.2
batch_size=128
model.compile(loss='categorical_crossentropy', optimizer='rmsprop',
              metrics=['accuracy'])
cl=CSVLogger(history_file)
es=EarlyStopping(monitor='val_loss', patience=12, verbose=1)
fit_log=model.fit(X_train, y_train, batch_size=batch_size,
                  epochs=n_epochs, validation_split=val_split,
                  callbacks=[cl, es])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 4s 193ms/step - loss: 0.7104 - accuracy: 0.4994 - val_loss: 0.6922 - val_accuracy: 0.5100
# Epoch 2/100
# 13/13 [==============================] - 2s 139ms/step - loss: 0.6900 - accuracy: 0.5300 - val_loss: 0.6869 - val_accuracy: 0.6325
# Epoch 3/100
# 13/13 [==============================] - 2s 147ms/step - loss: 0.6835 - accuracy: 0.5781 - val_loss: 0.6816 - val_accuracy: 0.5700
# Epoch 4/100
# 13/13 [==============================] - 2s 139ms/step - loss: 0
# Epoch 25/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.4789 - accuracy: 0.7738 - val_loss: 0.6734 - val_accuracy: 0.6500
# Epoch 26/100
# 13/13 [==============================] - 2s 166ms/step - loss: 0.4866 - accuracy: 0.7719 - val_loss: 0.6174 - val_accuracy: 0.6875
# Epoch 27/100
# 13/13 [==============================] - 2s 165ms/step - loss: 0.4546 - accuracy: 0.7788 - val_loss: 0.6003 - val_accuracy: 0.7050
# Epoch 28/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.4577 - accuracy: 0.7812 - val_loss: 0.5930 - val_accuracy: 0.6700
# Epoch 29/100
# 13/13 [==============================] - 3s 198ms/step - loss: 0.4535 - accuracy: 0.7788 - val_loss: 0.6005 - val_accuracy: 0.6750
# Epoch 30/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.4580 - accuracy: 0.7800 - val_loss: 0.6030 - val_accuracy: 0.7025
# Epoch 31/100
# 13/13 [==============================] - 2s 182ms/step - loss: 0.4311 - accuracy: 0.8037 - val_loss: 0.6249 - val_accuracy: 0.6600
# Epoch 32/100
# 13/13 [==============================] - 2s 182ms/step - loss: 0.4448 - accuracy: 0.7925 - val_loss: 0.6314 - val_accuracy: 0.7125
# Epoch 33/100
# 13/13 [==============================] - 2s 176ms/step - loss: 0.4076 - accuracy: 0.8075 - val_loss: 0.6189 - val_accuracy: 0.6500
# Epoch 34/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.4365 - accuracy: 0.7975 - val_loss: 0.6230 - val_accuracy: 0.6975
# Epoch 35/100
# 13/13 [==============================] - 2s 156ms/step - loss: 0.4259 - accuracy: 0.8075 - val_loss: 0.6139 - val_accuracy: 0.6950
# Epoch 36/100
# 13/13 [==============================] - 3s 264ms/step - loss: 0.3919 - accuracy: 0.8219 - val_loss: 0.6173 - val_accuracy: 0.6925
# Epoch 36: early stopping
# CPU times: total: 17min 58s
# Wall time: 1min 34s

# %% [markdown]
# #### Visualization of training progress

# %%
loss=fit_log.history['loss']
val_loss=fit_log.history['val_loss']
acc=fit_log.history['accuracy']
val_acc=fit_log.history['val_accuracy']
epoch=range(len(loss))

plt.plot(epoch, loss, label='train')
plt.plot(epoch, val_loss, label='valid')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epoch, acc, label='train')
plt.plot(epoch, val_acc, label='valid')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #### Visualization of training progress (from file)

# %%
df=pd.read_csv(history_file, sep=',', skiprows=0, header=0)
loss=df['loss']
val_loss=df['val_loss']
acc=df['accuracy']
val_acc=df['val_accuracy']
epoch=df['epoch']

plt.plot(epoch, loss, label='train')
plt.plot(epoch, val_loss, label='valid')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epoch, acc, label='train')
plt.plot(epoch, val_acc, label='valid')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #### Generalization performance

# %%
score=model.evaluate(X_test, y_test, verbose=0)
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# loss= 0.5574154853820801
# accuracy= 0.7149999737739563

# %%
y_test_pred=model.predict(X_test, verbose=0)
ct = pd.crosstab(y_test.argmax(axis=1),
                 y_test_pred.argmax(axis=1))
display(ct)
# Out:
# col_0    0    1
# row_0
# 0      137   63
# 1       51  149

# %% [markdown]
# #### Save model to file

# %%
model.save(model_file)
