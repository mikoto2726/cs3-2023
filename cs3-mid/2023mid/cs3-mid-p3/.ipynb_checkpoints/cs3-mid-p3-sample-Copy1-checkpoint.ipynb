# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_in = 'corona-data.csv'
df=pd.read_csv(csv_in, skiprows=0, header=0)

# %%
wday_list = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
weekend = wday_list[-2:]

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df=df.set_index('date')
df_week=df.resample('W').mean()
display(df_week)
# Out:
#             positive_cases
# date
# 2020-01-19        0.250000
# 2020-01-26        0.428571
# 2020-02-02        1.142857
# 2020-02-09        0.428571
# 2020-02-16        2.142857
# 2020-02-23       11.000000
# 2020-03-01       16.000000
# 2020-03-08       33.714286
# 2020-03-15       45.571429
# 2020-03-22       38.714286
# 2020-03-29      111.857143
# 2020-04-05      272.714286
# 2020-04-12      497.000000
# 2020-04-19      495.571429
# 2020-04-26      379.857143
# 2020-05-03      235.000000
# 2020-05-10      110.428571
# 2020-05-17       62.714286
# 2020-05-24       34.857143
# 2020-05-31       41.428571
# 2020-06-07       39.428571
# 2020-06-14       41.428571
# 2020-06-21       54.285714
# 2020-06-28       79.857143
# 2020-07-05      181.857143
# 2020-07-12      302.000000
# 2020-07-19      481.714286
# 2020-07-26      739.571429
# 2020-08-02     1220.142857
# 2020-08-09     1372.428571
# 2020-08-16     1038.142857
# 2020-08-23      934.857143
# 2020-08-30      753.000000
# 2020-09-06      560.000000
# 2020-09-13      532.142857
# 2020-09-20      491.857143
# 2020-09-27      428.142857
# 2020-10-04      500.285714
# 2020-10-11      511.428571
# 2020-10-18      526.000000
# 2020-10-25      564.000000
# 2020-11-01      687.142857
# 2020-11-08      909.142857
# 2020-11-15     1437.428571
# 2020-11-22     2047.142857
# 2020-11-29     2053.428571
# 2020-12-06     2186.285714
# 2020-12-13     2516.428571
# 2020-12-20     2649.571429
# 2020-12-27     3158.571429
# 2021-01-03     3597.500000

# %% [raw]
# 1791
# 2674
# 3270
# 3797
# 3934
# 3702
# 2942

# %%
df['day_of_week']=df.index.dayofweek

# %%
df_wday_ave=df.groupby('day_of_week').mean()

# %%
display(df_wday_ave)
# Out:
#              positive_cases
# day_of_week
# 0                431.180000
# 1                613.980000
# 2                723.520000
# 3                807.607843
# 4                738.060000
# 5                754.440000
# 6                597.240000

# %%
wday_list = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']  
weekend = wday_list[-2:]
plt.pie(wday_list,weekend)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 wday_list = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
#       2 weekend = wday_list[-2:]
# ----> 3 plt.pie(wday_list,weekend)
#       4 plt.show()
#
# File ~\miniconda3\envs\ds2023\lib\site-packages\matplotlib\pyplot.py:3006, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2999 @_copy_docstring_and_deprecators(Axes.pie)
#    3000 def pie(
#    3001         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
#    3008         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    3009         labeldistance=labeldistance, startangle=startangle,
#    3010         radius=radius, counterclock=counterclock,
#    3011         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    3012         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    3013         **({"data": data} if data is not None else {}))
#
# File ~\miniconda3\envs\ds2023\lib\site-packages\matplotlib\__init__.py:1361, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1358 @functools.wraps(func)
#    1359 def inner(ax, *args, data=None, **kwargs):
#    1360     if data is None:
# -> 1361         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1363     bound = new_sig.bind(ax, *args, **kwargs)
#    1364     auto_label = (bound.arguments.get(label_namer)
#    1365                   or bound.kwargs.get(label_namer))
#
# File ~\miniconda3\envs\ds2023\lib\site-packages\matplotlib\axes\_axes.py:3030, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3027 self.set_aspect('equal')
#    3028 # The use of float32 is "historical", but can't be changed without
#    3029 # regenerating the test baselines.
# -> 3030 x = np.asarray(x, np.float32)
#    3031 if x.ndim > 1:
#    3032     raise ValueError("x must be 1D")
#
# ValueError: could not convert string to float: 'Mon'
